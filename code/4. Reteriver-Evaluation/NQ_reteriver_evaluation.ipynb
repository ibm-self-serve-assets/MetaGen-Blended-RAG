# %% [markdown]
# ## Natural Questions (NQ) Retriever Evaluation with Elasticsearch
#
# This notebook demonstrates the evaluation of retrieval methods on the Natural Questions (NQ) dataset using Elasticsearch. It covers:
#
# - Loading and exploring the NQ dataset
# - Setting up Elasticsearch indices for BM25 and KNN retrieval
# - Implementing and evaluating different search strategies:
#     - Simple BM25 search
#     - Hybrid search using metadata fields
#     - KNN + Hybrid retriever evaluation
#
# The notebook provides code for querying Elasticsearch, comparing retrieved results with ground truth, and calculating retrieval accuracy.

# %%
import os
import re
from datetime import date
import pandas as pd
import json
from datetime import datetime
import requests

from pathlib import Path

from elasticsearch import Elasticsearch
from elasticsearch.exceptions import RequestError
import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv
import os

# Path to your .env file
env_path = "../.env"  # Change path if needed

# Load environment variables from .env
load_dotenv(dotenv_path=env_path)
# Access the environment variables
ES_URL = os.getenv("ES_URL")
ES_USER = os.getenv("ES_USER")
ES_PASS = os.getenv("ES_PASS")

# %%
# Create a global client connection to elastic search
es_client = Elasticsearch(
    ES_URL,
    basic_auth=(ES_USER, ES_PASS),
    verify_certs=False,
    request_timeout=10000
)

# %%
index_name_bm25 = "nq_bm25_metadata"
index_name_knn = "nq_knn_metadata"

# %% [markdown]
# ## 1. Evaluating on NQ DataSet

# %%
import pandas as pd
import json

from datasets import load_dataset
ds = load_dataset("facebook/kilt_tasks", "nq")

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 87372
#     })
#     validation: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 2837
#     })
#     test: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 1444
#     })
# })

# %%
validation_data = ds['validation']

# %%
type(validation_data)
# Out:
# datasets.arrow_dataset.Dataset

# %%
validation_data_df = pd.DataFrame(validation_data)
validation_data_df.head()
# Out:
#                      id                                              input  \
# 0   6915606477668963399                    what do the 3 dots mean in math
# 1  -8366545547296627039       who wrote the song photograph by ringo starr
# 2  -5004457603684974952  who is playing the halftime show at super bowl...
# 3   7217222058435937287  where was the world economic forum held this year
# 4   -143054837169120955  where are the giant redwoods located in califo...
#
#                                                 meta  \
# 0  {'left_context': '', 'mention': '', 'right_con...
# 1  {'left_context': '', 'mention': '', 'right_con...
# 2  {'left_context': '', 'mention': '', 'right_con...
# 3  {'left_context': '', 'mention': '', 'right_con...
# 4  {'left_context': '', 'mention': '', 'right_con...
#
#                                               output
# 0  [{'answer': 'the therefore sign', 'meta': {'sc...
# 1  [{'answer': 'Ringo Starr', 'meta': {'score': -...
# 2  [{'answer': 'Coldplay', 'meta': {'score': -1},...
# 3  [{'answer': 'Davos', 'meta': {'score': -1}, 'p...
# 4  [{'answer': 'Humboldt County', 'meta': {'score...

# %%
validation_data_df['output'][0]
# Out:
# [{'answer': 'the therefore sign',
#   'meta': {'score': -1},
#   'provenance': [{'bleu_score': 1.0,
#     'start_character': 44,
#     'start_paragraph_id': 1,
#     'end_character': 62,
#     'end_paragraph_id': 1,
#     'meta': {'fever_page_id': '',
#      'fever_sentence_id': -1,
#      'annotation_id': '-1',
#      'yes_no_answer': '',
#      'evidence_span': []},
#     'section': 'Section::::Abstract.',
#     'title': 'Therefore sign',
#     'wikipedia_id': '10593264'}]},
#  {'answer': 'therefore sign',
#   'meta': {'score': -1},
#   'provenance': [{'bleu_score': 1.0,
#     'start_character': 48,
#     'start_paragraph_id': 1,
#     'end_character': 62,
#     'end_paragraph_id': 1,
#     'meta': {'fever_page_id': '',
#      'fever_sentence_id': -1,
#      'annotation_id': '-1',
#      'yes_no_answer': '',
#      'evidence_span': []},
#     'section': 'Section::::Abstract.',
#     'title': 'Therefore sign',
#     'wikipedia_id': '10593264'}]},
#  {'answer': 'a logical consequence , such as the conclusion of a syllogism',
#   'meta': {'score': -1},
#   'provenance': []},
#  {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism',
#   'meta': {'score': -1},
#   'provenance': []},
#  {'answer': '',
#   'meta': {'score': -1},
#   'provenance': [{'bleu_score': 0.6816475987434387,
#     'start_character': 0,
#     'start_paragraph_id': 1,
#     'end_character': 375,
#     'end_paragraph_id': 1,
#     'meta': {'fever_page_id': '',
#      'fever_sentence_id': -1,
#      'annotation_id': '13591449469826568799',
#      'yes_no_answer': 'NONE',
#      'evidence_span': []},
#     'section': 'Section::::Abstract.',
#     'title': 'Therefore sign',
#     'wikipedia_id': '10593264'}]},
#  {'answer': '',
#   'meta': {'score': -1},
#   'provenance': [{'bleu_score': -1.0,
#     'start_character': -1,
#     'start_paragraph_id': 1,
#     'end_character': -1,
#     'end_paragraph_id': 1,
#     'meta': {'fever_page_id': '',
#      'fever_sentence_id': -1,
#      'annotation_id': '-1',
#      'yes_no_answer': '',
#      'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".',
#       'The symbol consists of three dots placed in an upright triangle and is read "therefore".',
#       'The symbol consists of three dots placed in an upright triangle and is read "therefore".',
#       'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']},
#     'section': 'Section::::Abstract.',
#     'title': 'Therefore sign',
#     'wikipedia_id': '10593264'}]}]

# %%
validation_data_df['output'][0][0]['provenance'][0]['title']
# Out:
# 'Therefore sign'

# %%
# knn_model_name ='sentence-transformers/multi-qa-MiniLM-L6-cos-v1'
knn_model_name = 'sentence-transformers/all-MiniLM-L6-v2'
from sentence_transformers import SentenceTransformer
model = SentenceTransformer(knn_model_name, trust_remote_code=True)

# %%
def processESIndex_simplesearch(df_questions,index_name,k):
    i =0
    count =0
    df_questions['model_op'] = ''
    for ind in df_questions.index:
        question = df_questions['input'][ind]
        print(question)
        search_query2 ={
                "query": {
                    "match": {
                    "context": question
                    }
                }
                }
        response = es_client.search(
        index=index_name,
        body=search_query2,
        size=k  # Set the number of documents to retrieve per scroll
        )
        all_hits = response['hits']['hits']
        print(len(all_hits))
        flag = False
        for num, doc in enumerate(all_hits):
            answer_ids = df_questions['output'][ind]
            for ids in answer_ids:
                print(ids)
                answer = ids['answer']
                if answer != '':
                    if len(ids['provenance']) >0:
                        if ids['provenance'][0]['title'] == doc["_source"]['title']:
                            flag = True
                            break
            print(flag)
        df_questions['model_op'][ind] = flag    
        i =i+1
    return df_questions

# %%
validation_data_df.shape

# %%
df_eval_k5 = validation_data_df.copy()
df_eval_k5=processESIndex_simplesearch(df_eval_k5,index_name_bm25,5)

# %%
df_eval_k5['model_op'].sum()/len(df_eval_k5)

# %% [markdown]
# ####  Metadata 1. keybert_title 2. yake_key_idea 3. entities

# %%
def processESIndex_Hybridsearch(df_questions,index_name,k):
    i =0
    count =0
    df_questions['model_op'] = ''
    for ind in df_questions.index:
        question = df_questions['input'][ind]
        print(question)
        search_query2 ={
          "query": {
           "multi_match" : {
              "query":question,
                "type":"best_fields",
                "fields": ["context","title","keybert_title"],
                #"fields": ["story^10","keybert_title^4", "title^8"],
                #  "fields": ["context^10","title^10","yake_key_idea","keybert_title^10"],
                "tie_breaker": 0.3
            }
          },
        }
        response = es_client.search(
        index=index_name,
        body=search_query2,
        size=k  # Set the number of documents to retrieve per scroll
        )
        all_hits = response['hits']['hits']
        print(len(all_hits))
        flag = False
        for num, doc in enumerate(all_hits):
            answer_ids = df_questions['output'][ind]
            for ids in answer_ids:
                print("******************", ids)
                answer = ids['answer']
                if answer != '':
                    print("----------------------", len(ids['provenance']))
                    if len(ids['provenance'])>0:
                        print("+++++++++++++++Golden title++++++++:", ids['provenance'][0]['title'])
                        print("+++++++++++++++Retrieved title++++++++:", doc["_source"]['title'])
                        if ids['provenance'][0]['title'] == doc["_source"]['title']:
                            flag = True
                            break
            print(flag)
        df_questions['model_op'][ind] = flag    
        i =i+1
    return df_questions

# %%
df_eval_k5 = validation_data_df.copy()
df_eval_k5 = processESIndex_Hybridsearch(df_eval_k5,index_name_bm25,5)

# %%
df_eval_k5.head()

# %%
score_val_k5 = (df_eval_k5['model_op']==True).sum()
print("Score Val ---",score_val_k5)
print("Score -------",score_val_k5/len(df_eval_k5))

# %% [markdown]
# ### KNN+ Reteriver Evaluation

# %%
import time
def processESIndex_KNN_Hybridsearch(df_questions,index_name,k):
    i =0
    count =0
    df_questions['model_op'] =''
    for ind in df_questions.index:
        question = df_questions['input'][ind]
        print(ind,"**********",question)
        search_query2 ={
          "query": {
           "multi_match" : {
              "query":question,
                "type":"best_fields",
                # "fields": ["context","title"],
                # "fields": ["context","title","keybert_title"],
                # "fields": ["story^10","keywords^2"],
                #"fields": ["story^10","entities^2","keybert_title^8","yake_key_idea^2"],
                 "fields": ["context^10","title^10","yake_key_idea","keybert_title^10"],
                "tie_breaker": 0.3
            }
          },
          "knn": {
                        "field": "contexts_embedding",
                        "query_vector": df_questions['question_embedding'][ind],
                        "k": k,
                        "num_candidates": 100,
                        "boost":10
                    },
        }
        response = es_client.search(
        index=index_name,
        body=search_query2,
        size=k  # Set the number of documents to retrieve per scroll
        )
        all_hits = response['hits']['hits']
        print(len(all_hits))
        flag = False
        for num, doc in enumerate(all_hits):
            answer_ids = df_questions['output'][ind]
            for ids in answer_ids:
                print("******************", ids)
                answer = ids['answer']
                if answer != '':
                    print("----------------------", len(ids['provenance']))
                    if len(ids['provenance'])>0:
                        #print("+++++++++++++++Golden title++++++++:", ids['provenance'][0]['title'])
                        #print("+++++++++++++++Retrieved title++++++++:", doc["_source"]['title'])
                        if ids['provenance'][0]['title'] == doc["_source"]['title']:
                            flag = True
                            break
            if flag:
                break
            print(flag)
        df_questions['model_op'][ind] = flag    
        i =i+1
        ##time.sleep(1)
    return df_questions

# %%
validation_data_df['question_embedding'] =''
for index, row in validation_data_df.iterrows():
    print("**********",index)
    question = row['input']
    validation_data_df.at[index,"question_embedding"] = model.encode(question)

# %%
validation_data_df.head()
# Out:
#                      id                                              input  \
# 0   6915606477668963399                    what do the 3 dots mean in math
# 1  -8366545547296627039       who wrote the song photograph by ringo starr
# 2  -5004457603684974952  who is playing the halftime show at super bowl...
# 3   7217222058435937287  where was the world economic forum held this year
# 4   -143054837169120955  where are the giant redwoods located in califo...
#
#                                                 meta  \
# 0  {'left_context': '', 'mention': '', 'right_con...
# 1  {'left_context': '', 'mention': '', 'right_con...
# 2  {'left_context': '', 'mention': '', 'right_con...
# 3  {'left_context': '', 'mention': '', 'right_con...
# 4  {'left_context': '', 'mention': '', 'right_con...
#
#                                               output  \
# 0  [{'answer': 'the therefore sign', 'meta': {'sc...
# 1  [{'answer': 'Ringo Starr', 'meta': {'score': -...
# 2  [{'answer': 'Coldplay', 'meta': {'score': -1},...
# 3  [{'answer': 'Davos', 'meta': {'score': -1}, 'p...
# 4  [{'answer': 'Humboldt County', 'meta': {'score...
#
#                                   question_embedding
# 0  [-0.021617994, -0.032326434, -0.046972573, -0....
# 1  [0.009027813, 0.078675, 0.036336917, 0.0033178...
# 2  [-0.015418596, 0.038507085, 0.015025766, -0.18...
# 3  [0.023470119, -0.049751315, -0.0731394, 0.0047...
# 4  [0.12426712, 0.05179882, 0.039753318, 0.065471...

# %%
df_eval_k5 = validation_data_df[0:100].copy()
df_eval_k5 = processESIndex_KNN_Hybridsearch(df_eval_k5,index_name_knn,5)
# Out:
# 0 ********** what do the 3 dots mean in math
# 5
# ****************** {'answer': 'the therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 44, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 48, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.6816475987434387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 375, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '13591449469826568799', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# False
# ****************** {'answer': 'the therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 44, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 48, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.6816475987434387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 375, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '13591449469826568799', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# False
# ****************** {'answer': 'the therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 44, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 48, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.6816475987434387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 375, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '13591449469826568799', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# False
# ****************** {'answer': 'the therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 44, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 48, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.6816475987434387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 375, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '13591449469826568799', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# False
# ****************** {'answer': 'the therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 44, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'therefore sign', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 48, 'start_paragraph_id': 1, 'end_character': 62, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ---------------------- 1
# ****************** {'answer': 'a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'the therefore sign ( ∴ ) is generally used before a logical consequence , such as the conclusion of a syllogism', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.6816475987434387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 375, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '13591449469826568799', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'The symbol consists of three dots placed in an upright triangle and is read "therefore".', 'In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read "therefore". It is encoded at .']}, 'section': 'Section::::Abstract.', 'title': 'Therefore sign', 'wikipedia_id': '10593264'}]}
# False
# 1 ********** who wrote the song photograph by ringo starr
# 5
# ****************** {'answer': 'Ringo Starr', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 12, 'start_paragraph_id': 0, 'end_character': 23, 'end_paragraph_id': 0, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Photograph (Ringo Starr song)', 'wikipedia_id': '2448355'}]}
# ---------------------- 1
# 2 ********** who is playing the halftime show at super bowl 2016
# 5
# ****************** {'answer': 'Coldplay', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 178, 'start_paragraph_id': 1, 'end_character': 186, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Super Bowl 50 halftime show', 'wikipedia_id': '45267196'}]}
# ---------------------- 1
# 3 ********** where was the world economic forum held this year
# 5
# ****************** {'answer': 'Davos', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 57, 'start_paragraph_id': 2, 'end_character': 62, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'World Economic Forum', 'wikipedia_id': '172185'}]}
# ---------------------- 1
# 4 ********** where are the giant redwoods located in california
# 5
# ****************** {'answer': 'Humboldt County', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 172, 'start_paragraph_id': 9, 'end_character': 187, 'end_paragraph_id': 9, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::History.\n', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ---------------------- 1
# ****************** {'answer': 'the coast of northern California', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 130, 'start_paragraph_id': 1, 'end_character': 162, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ---------------------- 1
# ****************** {'answer': 'from the northern California coast north to the southern Oregon Coast', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': 'Del Norte County', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 0, 'start_paragraph_id': 0, 'end_character': 0, 'end_paragraph_id': 0, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '16665979442690208418', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.8094519972801208, 'start_character': 0, 'start_paragraph_id': 18, 'end_character': 450, 'end_paragraph_id': 18, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '16665979442690208418', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Natural resources.:Flora.\n', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.8696358799934387, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 862, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '16665979442690208418', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California's Sierra Nevada.", 'Redwood Mountain Grove is the largest grove of giant sequoia ("Sequoiadendron giganteum") trees on earth. It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California\'s Sierra Nevada.', 'Redwood Mountain Grove is the largest grove of giant sequoia ("Sequoiadendron giganteum") trees on earth. It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California\'s Sierra Nevada.']}, 'section': 'Section::::Abstract.', 'title': 'Redwood Mountain Grove', 'wikipedia_id': '5047618'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California.', 'The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California. The forest is drained by High Prairie Creek.', 'The Redwood Experimental Forest (also Yurok Redwood Experimental Forest, formerly Yurok Experimental Forest) (established 1940) is an experimental forest in Del Norte County, California. The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California.', 'The Redwood Experimental Forest (also Yurok Redwood Experimental Forest, formerly Yurok Experimental Forest) (established 1940) is an experimental forest in Del Norte County, California. The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California. The forest is drained by High Prairie Creek. As its name implies, the principal species in the forest is coast redwood ("Sequoia sempervirens"), but the site also contains Douglas fir, Sitka spruce, western hemlock, and Port Orford cedar.']}, 'section': 'Section::::Abstract.', 'title': 'Redwood Experimental Forest', 'wikipedia_id': '50612691'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Humboldt Counties, the four parks, together, protect 45% of all remaining coast redwood ("Sequoia sempervirens") old-growth forests, totaling at least', 'located in the United States, along the coast of northern California.', 'The Redwood National and State Parks (RNSP) are a complex of several state and national parks located in the United States, along the coast of northern California.', 'Located entirely within Del Norte and Humboldt Counties, the four parks, together, protect 45% of all remaining coast redwood ("Sequoia sempervirens") old-growth forests, totaling at least .']}, 'section': 'Section::::Abstract.', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The Roosevelt tree is the largest giant sequoia ("Sequoiadendron giganteum") in Redwood Mountain Grove, which is itself the largest grove of giant sequoias on Earth, which are endemic to the Sierra Nevada of California.', 'The Roosevelt tree is the largest giant sequoia ("Sequoiadendron giganteum") in Redwood Mountain Grove, which is itself the largest grove of giant sequoias on Earth, which are endemic to the Sierra Nevada of California', 'The Roosevelt tree is the largest giant sequoia ("Sequoiadendron giganteum") in Redwood Mountain Grove, which is itself the largest grove of giant sequoias on Earth, which are endemic to the Sierra Nevada of California']}, 'section': 'Section::::Abstract.', 'title': 'Roosevelt (tree)', 'wikipedia_id': '23413133'}]}
# False
# ****************** {'answer': 'Humboldt County', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 172, 'start_paragraph_id': 9, 'end_character': 187, 'end_paragraph_id': 9, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::History.\n', 'title': 'Redwood National and State Parks', 'wikipedia_id': '758737'}]}
# ---------------------- 1
# 5 ********** who has made the most premier league appearances
# 5
# ****************** {'answer': 'Gareth Barry', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 571, 'start_paragraph_id': 2, 'end_character': 583, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ---------------------- 1
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.9391489624977112, 'start_character': 0, 'start_paragraph_id': 2, 'end_character': 873, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '11568032619189358823', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "The first player to reach the milestone was midfielder Gary Speed, in representation of Leeds United, Everton, Newcastle United and Bolton Wanderers; his 500th match was Bolton's 40 win over West Ham United on 9 December 2006. Speed held the record for most appearances until 14 February 2009, when goalkeeper David James played his 536th match, for Portsmouth against his former team Manchester City. James ended with 572 appearances, a record which was broken by Ryan Giggs on 14 May 2011, having played all of his matches for Manchester United. On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal. At the time of breaking the record, Barry ranked 8th in English top division appearances since the Second World War, trailing Giggs in 6th (672 total top division appearances) and six other players."]}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# False
# ****************** {'answer': 'Gareth Barry', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 571, 'start_paragraph_id': 2, 'end_character': 583, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ---------------------- 1
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.9391489624977112, 'start_character': 0, 'start_paragraph_id': 2, 'end_character': 873, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '11568032619189358823', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "The first player to reach the milestone was midfielder Gary Speed, in representation of Leeds United, Everton, Newcastle United and Bolton Wanderers; his 500th match was Bolton's 40 win over West Ham United on 9 December 2006. Speed held the record for most appearances until 14 February 2009, when goalkeeper David James played his 536th match, for Portsmouth against his former team Manchester City. James ended with 572 appearances, a record which was broken by Ryan Giggs on 14 May 2011, having played all of his matches for Manchester United. On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal. At the time of breaking the record, Barry ranked 8th in English top division appearances since the Second World War, trailing Giggs in 6th (672 total top division appearances) and six other players."]}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# False
# ****************** {'answer': 'Gareth Barry', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 571, 'start_paragraph_id': 2, 'end_character': 583, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ---------------------- 1
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.9391489624977112, 'start_character': 0, 'start_paragraph_id': 2, 'end_character': 873, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '11568032619189358823', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal", "The first player to reach the milestone was midfielder Gary Speed, in representation of Leeds United, Everton, Newcastle United and Bolton Wanderers; his 500th match was Bolton's 40 win over West Ham United on 9 December 2006. Speed held the record for most appearances until 14 February 2009, when goalkeeper David James played his 536th match, for Portsmouth against his former team Manchester City. James ended with 572 appearances, a record which was broken by Ryan Giggs on 14 May 2011, having played all of his matches for Manchester United. On 25 September 2017, Gareth Barry broke Giggs' record by playing his 633rd match, West Bromwich Albion's 20 loss at Arsenal. At the time of breaking the record, Barry ranked 8th in English top division appearances since the Second World War, trailing Giggs in 6th (672 total top division appearances) and six other players."]}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# False
# ****************** {'answer': 'Gareth Barry', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 571, 'start_paragraph_id': 2, 'end_character': 583, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of Premier League players with 500 or more appearances', 'wikipedia_id': '45554141'}]}
# ---------------------- 1
# 6 ********** who was the first chief minister of west bengal
# 5
# ****************** {'answer': 'Prafulla Chandra Ghosh', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 218, 'start_paragraph_id': 2, 'end_character': 240, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ---------------------- 1
# ****************** {'answer': 'Prafulla Chandra Ghosh of the Indian National Congress', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["In August 1947, the British Indian province of Bengal was partitioned into the Pakistani province of East Bengal and the Indian state of West Bengal. Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term. A period of political instability followedWest Bengal witnessed three elections, four coalition governments and three stints of President's rule between 1967 and 1972before Siddhartha Shankar Ray of the INC served a five-year term.", 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party.', 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term.']}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 102, 'end_character': -1, 'end_paragraph_id': 102, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Cyclotron Centre are the most prominent. Notable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy; statisticians Prasanta Chandra Mahalanobis and Anil Kumar Gain; physician Upendranath Brahmachari; educator Ashutosh Mukherjee; and Nobel laureates Rabindranath Tagore, C. V. Raman, and Amartya Sen. In 2005 West Bengal had 505 published newspapers, of which 389 were in Bengali. "Ananda Bazar Patrika", published from Kolkata with 1,277,801', 'otable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy']}, 'section': 'Section::::Education.\n', 'title': 'West Bengal', 'wikipedia_id': '34040'}]}
# False
# ****************** {'answer': 'Prafulla Chandra Ghosh', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 218, 'start_paragraph_id': 2, 'end_character': 240, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ---------------------- 1
# ****************** {'answer': 'Prafulla Chandra Ghosh of the Indian National Congress', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["In August 1947, the British Indian province of Bengal was partitioned into the Pakistani province of East Bengal and the Indian state of West Bengal. Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term. A period of political instability followedWest Bengal witnessed three elections, four coalition governments and three stints of President's rule between 1967 and 1972before Siddhartha Shankar Ray of the INC served a five-year term.", 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party.', 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term.']}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 102, 'end_character': -1, 'end_paragraph_id': 102, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Cyclotron Centre are the most prominent. Notable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy; statisticians Prasanta Chandra Mahalanobis and Anil Kumar Gain; physician Upendranath Brahmachari; educator Ashutosh Mukherjee; and Nobel laureates Rabindranath Tagore, C. V. Raman, and Amartya Sen. In 2005 West Bengal had 505 published newspapers, of which 389 were in Bengali. "Ananda Bazar Patrika", published from Kolkata with 1,277,801', 'otable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy']}, 'section': 'Section::::Education.\n', 'title': 'West Bengal', 'wikipedia_id': '34040'}]}
# False
# ****************** {'answer': 'Prafulla Chandra Ghosh', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 218, 'start_paragraph_id': 2, 'end_character': 240, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ---------------------- 1
# ****************** {'answer': 'Prafulla Chandra Ghosh of the Indian National Congress', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["In August 1947, the British Indian province of Bengal was partitioned into the Pakistani province of East Bengal and the Indian state of West Bengal. Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term. A period of political instability followedWest Bengal witnessed three elections, four coalition governments and three stints of President's rule between 1967 and 1972before Siddhartha Shankar Ray of the INC served a five-year term.", 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party.', 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term.']}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 102, 'end_character': -1, 'end_paragraph_id': 102, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Cyclotron Centre are the most prominent. Notable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy; statisticians Prasanta Chandra Mahalanobis and Anil Kumar Gain; physician Upendranath Brahmachari; educator Ashutosh Mukherjee; and Nobel laureates Rabindranath Tagore, C. V. Raman, and Amartya Sen. In 2005 West Bengal had 505 published newspapers, of which 389 were in Bengali. "Ananda Bazar Patrika", published from Kolkata with 1,277,801', 'otable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy']}, 'section': 'Section::::Education.\n', 'title': 'West Bengal', 'wikipedia_id': '34040'}]}
# False
# ****************** {'answer': 'Prafulla Chandra Ghosh', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 218, 'start_paragraph_id': 2, 'end_character': 240, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ---------------------- 1
# ****************** {'answer': 'Prafulla Chandra Ghosh of the Indian National Congress', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["In August 1947, the British Indian province of Bengal was partitioned into the Pakistani province of East Bengal and the Indian state of West Bengal. Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term. A period of political instability followedWest Bengal witnessed three elections, four coalition governments and three stints of President's rule between 1967 and 1972before Siddhartha Shankar Ray of the INC served a five-year term.", 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party.', 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term.']}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 102, 'end_character': -1, 'end_paragraph_id': 102, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Cyclotron Centre are the most prominent. Notable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy; statisticians Prasanta Chandra Mahalanobis and Anil Kumar Gain; physician Upendranath Brahmachari; educator Ashutosh Mukherjee; and Nobel laureates Rabindranath Tagore, C. V. Raman, and Amartya Sen. In 2005 West Bengal had 505 published newspapers, of which 389 were in Bengali. "Ananda Bazar Patrika", published from Kolkata with 1,277,801', 'otable scholars who were born, worked, or studied in the geographic area of the state include physicists Satyendra Nath Bose, Meghnad Saha, and Jagadish Chandra Bose; chemist Prafulla Chandra Roy']}, 'section': 'Section::::Education.\n', 'title': 'West Bengal', 'wikipedia_id': '34040'}]}
# False
# ****************** {'answer': 'Prafulla Chandra Ghosh', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 218, 'start_paragraph_id': 2, 'end_character': 240, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ---------------------- 1
# ****************** {'answer': 'Prafulla Chandra Ghosh of the Indian National Congress', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 2, 'end_character': -1, 'end_paragraph_id': 2, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ["In August 1947, the British Indian province of Bengal was partitioned into the Pakistani province of East Bengal and the Indian state of West Bengal. Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term. A period of political instability followedWest Bengal witnessed three elections, four coalition governments and three stints of President's rule between 1967 and 1972before Siddhartha Shankar Ray of the INC served a five-year term.", 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party.', 'Since then West Bengal has had eight chief ministers, starting with Prafulla Chandra Ghosh of the Indian National Congress (INC) party. His five-month stint as Prime Minister of West Bengalas the office was known until January 1950was succeeded by the 14-year reign of colleague Bidhan Chandra Roy, whose death in 1962 led to Prafulla Chandra Sen serving out the remainder of his term.']}, 'section': 'Section::::Abstract.', 'title': 'List of chief ministers of West Bengal', 'wikipedia_id': '2382949'}]}
# ...
# ---------------------- 1
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 0, 'start_paragraph_id': 0, 'end_character': 0, 'end_paragraph_id': 0, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '1971030759276330397', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Robber baron (industrialist)', 'wikipedia_id': '2385379'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.7898179888725281, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 187, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '1971030759276330397', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Robber baron (industrialist)', 'wikipedia_id': '2385379'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['"Robber baron" is a derogatory metaphor of social criticism originally applied to certain late 19th-century American businessmen who were accused of using unscrupulous methods to get rich, or expand their wealth, for example Cornelius Vanderbilt taking money from government-subsidized shippers, in order to not compete on their routes.', 'Robber baron" is a derogatory metaphor of social criticism originally applied to certain late 19th-century American businessmen who were accused of using unscrupulous methods to get rich, or expand their wealth, for example Cornelius Vanderbilt taking money from government-subsidized shippers, in order to not compete on their routes.', '"Robber baron" is a derogatory metaphor of social criticism originally applied to certain late 19th-century American businessmen who were accused of using unscrupulous methods to get rich, or expand their wealth,']}, 'section': 'Section::::Abstract.', 'title': 'Robber baron (industrialist)', 'wikipedia_id': '2385379'}]}
# False
# 95 ********** who is young george bailey in it's a wonderful life
# 5
# ****************** {'answer': 'Robert James Anderson', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 21, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Bobby Anderson (actor)', 'wikipedia_id': '17835985'}]}
# ---------------------- 1
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.9383861422538757, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 177, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '7509438588482337892', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Bobby Anderson (actor)', 'wikipedia_id': '17835985'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 5, 'end_character': -1, 'end_paragraph_id': 5, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Lane spent a short time as an insurance salesman before taking to the stage at the Pasadena Playhouse. Actor/director Irving Pichel first suggested that Lane go into acting in 1929, and four years later Lane was a founding member of the Screen Actors Guild. He became a favorite of director Frank Capra, who used him in several films. In "It\'s a Wonderful Life", Lane played a seemingly hard-nosed rent collector for the miserly Henry Potter (Lionel Barrymore), who tried to explain to his employer that many of his tenants were moving out, taking advantage of affordable mortgage loans provided by the film\'s protagonist, George Bailey (James Stewart). Lane also appeared in the film "Mighty Joe Young" (1949) as one of the reporters cajoling Max O\'Hara (Robert Armstrong) for information about the identity of "Mr. Joseph Young", the persona given featured billing on the front of the building, on opening night.', 'Lane spent a short time as an insurance salesman before taking to the stage at the Pasadena Playhouse. Actor/director Irving Pichel first suggested that Lane go into acting in 1929, and four years later Lane was a founding member of the Screen Actors Guild. He became a favorite of director Frank Capra, who used him in several films. In "It\'s a Wonderful Life", Lane played a seemingly hard-nosed rent collector for the miserly Henry Potter (Lionel Barrymore), who tried to explain to his employer that many of his tenants were moving out, taking advantage of affordable mortgage loans provided by the film\'s protagonist, George Bailey (James Stewart). Lane also appeared in the film "Mighty Joe Young" (1949) as one of the reporters cajoling Max O\'Hara (Robert Armstrong) for information about the identity of "Mr. Joseph Young", the persona given featured billing on the front of the building, on opening night.']}, 'section': 'Section::::Career.\n', 'title': 'Charles Lane (actor)', 'wikipedia_id': '555690'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 3, 'end_character': -1, 'end_paragraph_id': 3, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Jason James Richter (born January 29, 1980) is an American actor and musician, most commonly known for his role in the "Free Willy" film series as Jesse, the boy who befriends Willy. Richter was born in Medford, Oregon, the son of Sandra Dionne (née Dunham), an actress, and Gregory Lynn Richter, who was in the U.S. Navy. At the age of three, he and his family moved to Hawaii, where a Japanese casting agency discovered him and signed him up for three TV spots. In 1989, his family moved to Los Angeles, where he could pursue his career.', 'Jason James Richter (born January 29, 1980) is an American actor and musician, most commonly known for his role in the "Free Willy" film series as Jesse, the boy who befriends Willy. Richter was born in Medford, Oregon, the son of Sandra Dionne (née Dunham), an actress, and Gregory Lynn Richter, who was in the U.S. Navy. At the age of three, he and his family moved to Hawaii, where a Japanese casting agency discovered him and signed him up for three TV spots. In 1989, his family moved to Los Angeles, where he could pursue his career.']}, 'section': 'Section::::Early life.\n', 'title': 'Jason James Richter', 'wikipedia_id': '700183'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['It\'s a Great Day is a 1955 British comedy film directed by John Warrington. A spin-off of the popular soap "The Grove Family", the film stars Ruth Dunning as Gladys Grove, Edward Evans as Bob Grove, and Sid James as Harry Mason.', 'It\'s a Great Day is a 1955 British comedy film directed by John Warrington. A spin-off of the popular soap "The Grove Family", the film stars Ruth Dunning as Gladys Grove, Edward Evans as Bob Grove, and Sid James as Harry Mason.']}, 'section': 'Section::::Abstract.', 'title': "It's a Great Day", 'wikipedia_id': '19421173'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Robert James Anderson (March 6, 1933 June 6, 2008) was an American actor and television producer, most famous for his role as the young George Bailey in "It\'s a Wonderful Life".', 'Robert James Anderson (March 6, 1933 June 6, 2008) was an American actor and television producer, most famous for his role as the young George Bailey in "It\'s a Wonderful Life".', 'Robert James Anderson (March 6, 1933 June 6, 2008) was an American actor and television producer, most famous for his role as the young George Bailey in "It\'s a Wonderful Life".']}, 'section': 'Section::::Abstract.', 'title': 'Bobby Anderson (actor)', 'wikipedia_id': '17835985'}]}
# False
# ****************** {'answer': 'Robert James Anderson', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 0, 'start_paragraph_id': 1, 'end_character': 21, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Bobby Anderson (actor)', 'wikipedia_id': '17835985'}]}
# ---------------------- 1
# 96 ********** who won the battle of stirling bridge 1297
# 5
# ****************** {'answer': 'Andrew Moray', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 122, 'start_paragraph_id': 1, 'end_character': 134, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Battle of Stirling Bridge', 'wikipedia_id': '44782'}]}
# ---------------------- 1
# 97 ********** who plays dylan in daddy's home 2
# 5
# ****************** {'answer': 'Owen Vaccaro', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 382, 'start_paragraph_id': 24, 'end_character': 394, 'end_paragraph_id': 24, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Production.\n', 'title': "Daddy's Home 2", 'wikipedia_id': '50318856'}]}
# ---------------------- 1
# 98 ********** where is the tablet of the ten commandments
# 5
# ****************** {'answer': 'Ark of the Covenant', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 100, 'start_paragraph_id': 4, 'end_character': 119, 'end_paragraph_id': 4, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Tablets of Stone', 'wikipedia_id': '1651770'}]}
# ---------------------- 1
# ****************** {'answer': 'in the Ark of the Covenant', 'meta': {'score': -1}, 'provenance': []}
# ---------------------- 0
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 0.7613428235054016, 'start_character': 0, 'start_paragraph_id': 4, 'end_character': 149, 'end_paragraph_id': 4, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '3852143126379180628', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Tablets of Stone', 'wikipedia_id': '1651770'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 0, 'start_paragraph_id': 0, 'end_character': 0, 'end_paragraph_id': 0, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '3852143126379180628', 'yes_no_answer': 'NONE', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Tablets of Stone', 'wikipedia_id': '1651770'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 52, 'end_character': -1, 'end_paragraph_id': 52, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['Synagogue construction over the last two thousand years has followed the outlines of the original tabernacle. Every synagogue has at its front an ark, "aron kodesh", containing the Torah scrolls, comparable to the Ark of the Covenant which contained the tablets with Ten Commandments.', 'the Ark of the Covenant which contained the tablets with Ten Commandments', 'the Ark of the Covenant which contained the tablets with Ten Commandments']}, 'section': 'Section::::Blueprint for synagogues.\n', 'title': 'Tabernacle', 'wikipedia_id': '82935'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 4, 'end_character': -1, 'end_paragraph_id': 4, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['According to the bible, both the first shattered set and the second unbroken set were stored in the Ark of the Covenant, and is outlined in Have the people make an Ark of acacia wooda sacred chest 45 inches long, 27 inches wide, and 27 inches high.', 'According to the bible, both the first shattered set and the second unbroken set were stored in the Ark of the Covenant', 'both the first shattered set and the second unbroken set were stored in the Ark of the Covenant']}, 'section': 'Section::::Abstract.', 'title': 'Tablets of Stone', 'wikipedia_id': '1651770'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The Ark according to Hebrew Scripture contained the Ten Commandments, which were given by God to Moses on Mount Sinai. King Solomon built the Temple in Jerusalem, where the Ark of the Covenant was supposed to be kept.', 'The Ark according to Hebrew Scripture contained the Ten Commandments']}, 'section': 'Section::::Abstract.', 'title': 'Holy of Holies', 'wikipedia_id': '684758'}]}
# ****************** {'answer': '', 'meta': {'score': -1}, 'provenance': [{'bleu_score': -1.0, 'start_character': -1, 'start_paragraph_id': 1, 'end_character': -1, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': ['The Ark of the Covenant (), also known as the Ark of the Testimony, and in a few verses across various translations as the Ark of God, is a gold-covered wooden chest with lid cover described in the Book of Exodus as containing the two stone tablets of the Ten Commandments.', 'described in the Book of Exodus as containing the two stone tablets of the Ten Commandments']}, 'section': 'Section::::Abstract.', 'title': 'Ark of the Covenant', 'wikipedia_id': '2134'}]}
# False
# ****************** {'answer': 'Ark of the Covenant', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 100, 'start_paragraph_id': 4, 'end_character': 119, 'end_paragraph_id': 4, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Tablets of Stone', 'wikipedia_id': '1651770'}]}
# ---------------------- 1
# 99 ********** when did the right to buy scheme start
# 5
# ****************** {'answer': '1980', 'meta': {'score': -1}, 'provenance': [{'bleu_score': 1.0, 'start_character': 535, 'start_paragraph_id': 1, 'end_character': 539, 'end_paragraph_id': 1, 'meta': {'fever_page_id': '', 'fever_sentence_id': -1, 'annotation_id': '-1', 'yes_no_answer': '', 'evidence_span': []}, 'section': 'Section::::Abstract.', 'title': 'Right to Buy', 'wikipedia_id': '2063383'}]}
# ---------------------- 1

# %%
score_val_k5 = (df_eval_k5['model_op']==True).sum()
print("Score Val ---",score_val_k5)
print("Score -------",score_val_k5/len(df_eval_k5))
# Out:
# Score Val --- 63
# Score ------- 0.63
